# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("vehiclesFinal.csv")
df
# Out:
#                 id                region    year manufacturer  \
# 0       7119256118         mohave county  2012.0         jeep
# 1       7120880186          oregon coast  2014.0          bmw
# 2       7115048251  greenville / upstate  2001.0        dodge
# 3       7119250502         mohave county  2004.0    chevrolet
# 4       7120430837                 maine  2005.0         ford
# ...            ...                   ...     ...          ...
# 374217  7115048966  greenville / upstate  2019.0         ford
# 374218  7112219717  rapid city / west SD  2002.0       toyota
# 374219  7120896708          oregon coast  2001.0         ford
# 374220  7120885819          oregon coast  2013.0        mazda
# 374221  7112215161  rapid city / west SD  2010.0        dodge
#
#                               model  condition    cylinders    fuel  odometer  \
# 0                           patriot   like new  4 cylinders     gas  247071.0
# 1                      328i m-sport       good  5 cylinders     gas   76237.0
# 2                           caravan  excellent  6 cylinders     gas  199000.0
# 3                       colorado ls  excellent  5 cylinders     gas   54000.0
# 4               mustang convertible  excellent  6 cylinders     gas   62800.0
# ...                             ...        ...          ...     ...       ...
# 374217  f250 diesel powerstroke 4x4   like new  8 cylinders  diesel   55000.0
# 374218                        camry       good  6 cylinders     gas  194000.0
# 374219                        focus       good  4 cylinders     gas  130484.0
# 374220                       mazda3       fair  5 cylinders     gas   93339.0
# 374221                grand caravan       fair  5 cylinders     gas  148721.0
#
#        title_status transmission drive       size         type paint_color  \
# 0             clean    automatic   4wd  full-size      offroad      silver
# 1             clean    automatic   rwd  full-size        sedan        grey
# 2             clean    automatic   4wd  full-size      offroad        grey
# 3             clean    automatic   rwd   mid-size       pickup         red
# 4             clean    automatic   rwd   mid-size  convertible      silver
# ...             ...          ...   ...        ...          ...         ...
# 374217        clean    automatic   4wd  full-size       pickup       white
# 374218        clean    automatic   fwd  full-size      offroad        blue
# 374219        clean    automatic   rwd    compact        other       black
# 374220        clean    automatic   fwd  full-size        sedan        grey
# 374221        clean    automatic   fwd  full-size     mini-van        blue
#
#             lat      long  price
# 0       34.4554 -114.2690   3495
# 1       46.1837 -123.8240  13750
# 2       34.9352  -81.9654   2300
# 3       34.4783 -114.2710   9000
# 4       44.2070  -69.7858   8500
# ...         ...       ...    ...
# 374217  34.8001  -82.3932  46995
# 374218  44.0036 -103.3590   2700
# 374219  45.5272 -123.0950   2450
# 374220  45.5231 -122.5790   8995
# 374221  44.0804 -103.1910   6577
#
# [374222 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# id              0
# region          0
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# size            0
# type            0
# paint_color     0
# lat             0
# long            0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (374222, 18)

# %%
df.columns
# Out:
# Index(['id', 'region', 'year', 'manufacturer', 'model', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission',
#        'drive', 'size', 'type', 'paint_color', 'lat', 'long', 'price'],
#       dtype='object')

# %%
df2=df.sample(100)
df2.shape
# Out:
# (100, 18)

# %%
sns.pairplot(df2)
plt.title('Figure 1: Pair Plot')
plt.tight_layout()
plt.savefig('Insight-Pair-Plot',dpi=None)
plt.show()

# %%
sns.distplot(df.price)
plt.tight_layout()
plt.title("Distribution of price")
plt.savefig('Insight-Dist-Plot',dpi=None)
plt.show()
# Out:
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig,axs=plt.subplots()
fig.set_size_inches(5,5)

p1=sns.barplot(x='fuel',y='price',data=df,ax=axs)
axs.set_title('Figure 1')

plt.savefig('Insight-Figure-1',dpi=None)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='fuel',y='price',hue='condition',data=df)
plt.title('Figure 2')
plt.savefig('Insight-Figure-2',dpi=None)
plt.show()

# %%
fig,axs=plt.subplots(nrows=2)
fig.set_size_inches(20,10)
sns.barplot(x='year',y='price',data=df,ax=axs[0])
sns.barplot(df.groupby('year').count()['price'].index,df.groupby('year').count()['price'].values,ax=axs[1])
axs[0].set_title('Figure 3')
axs[1].set_title('Figure 4')
axs[1].set_ylabel('Number of cars')
plt.tight_layout()
plt.savefig('Insight-Figure-3-4.jpg',dpi=600)
plt.show()
# Out:
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,axs=plt.subplots(ncols=2)
fig.set_size_inches(12,4)
sns.barplot(x='condition',y='price',data=df,ax=axs[0])
sns.barplot(x='condition',y='price',hue='size',data=df,ax=axs[1])
axs[0].set_title('Figure 5')
axs[1].set_title('Figure 6')
plt.tight_layout()
plt.savefig('Insight-Figure-5-6.jpg',dpi=600)
plt.show()

# %%
fig,axs=plt.subplots(ncols=2)
fig.set_size_inches(12,4)
sns.barplot(x='transmission',y='price',data=df,ax=axs[0])
sns.barplot(x='transmission',y='price',hue='size',data=df,ax=axs[1])
axs[0].set_title('Figure 7')
axs[1].set_title('Figure 8')
plt.tight_layout()
plt.savefig('Insight-Figure-7-8.jpg',dpi=600)
plt.show()

# %%
fig,axs=plt.subplots(ncols=2)
fig.set_size_inches(12,4)
sns.barplot(x='size',y='price',data=df,ax=axs[0])
sns.barplot(x='size',y='price',hue='drive',data=df,ax=axs[1])
axs[0].set_title('Figure 11')
axs[1].set_title('Figure 12')
plt.tight_layout()
plt.savefig('Insight-Figure-11-12.jpg',dpi=600)
plt.show()

# %%
fig,axs=plt.subplots(ncols=2)
fig.set_size_inches(10,4)
sns.barplot(df.groupby('condition').count()['price'].index,df.groupby('condition').count()['price'].values,ax=axs[0])
sns.barplot(df.groupby('transmission').count()['price'].index,df.groupby('transmission').count()['price'].values,ax=axs[1])
axs[0].set_ylabel('Number of cars')
axs[0].set_title('Figure 17')
axs[1].set_ylabel('Number of cars')
axs[1].set_title('Figure 18')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,axs=plt.subplots(ncols=2)
fig.set_size_inches(10,5)
sns.barplot(df.groupby('fuel').count()['price'].index,df.groupby('fuel').count()['price'].values,ax=axs[0])
sns.barplot(df.groupby('size').count()['price'].index,df.groupby('size').count()['price'].values,ax=axs[1])
axs[0].set_ylabel('Number of cars')
axs[0].set_title('Figure 21')
axs[1].set_ylabel('Number of cars')
axs[1].set_title('Figure 22')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\swethak\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
